# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.options.display.float_format = "{:,.2f}".format
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
import warnings
warnings.simplefilter("ignore")

# %%
storebranch = pd.read_csv('storebranch.csv')
shoopers = pd.read_csv('shoppers.csv')
orders = pd.read_csv('orders.csv')
order_product=pd.read_csv('order_product.csv')

# %%
orders
# Out:
#                               order_id   lat     lng  dow promised_time  \
# 0     6abd5e28d01b7c733fe37485294235dc 18.22 -100.31    2      13:00:00
# 1     0d37a1eea001f01b40232ffd496ff663 18.18 -100.36    2      13:00:00
# 2     528428e9b9eb5d3bd0dbdd8da692b087 18.27 -100.32    2      11:00:00
# 3     d3f7be6d64eae7405b7bf024e04807a2 18.25 -100.32    2      10:00:00
# 4     e0ad6533b6cd9a382ec6c1d473c5036c 18.23 -100.32    2      11:00:00
# ...                                ...   ...     ...  ...           ...
# 7290  d2f2a9bd2a4c0768aafaf3d169dca8ee 18.23 -100.39    2      15:00:00
# 7291  e813a2be0ff5f6f43e50eb4d876c49ac 18.22 -100.41    2      12:00:00
# 7292  521a26393f81cf403f7fcc5093e73665 18.28 -100.35    2      13:00:00
# 7293  13c6390a1cc8fbab23db8c2d38a56bd1 18.29 -100.33    2      11:00:00
# 7294  7ffa2d60aea99143b28564d737ca4b2b 18.19 -100.35    4      23:00:00
#
#      actual_time  on_demand                         picker_id  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-6222a8950483> in <module>
# ----> 1 orders['actual_time'].type()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
orders_teste=orders

# %%
orders_teste['delivered']=delivered que é

# %%
for i in orders['actual_time']:
    print('')
# Out:
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# ...

# %%
df3= pd.concat([df1, df2])

# %%
orders_teste['new_formatted_date'] = orders_teste[['actual_time']].strftime('%H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-d28a20935cf4> in <module>
# ----> 1 orders_teste['new_formatted_date'] = orders_teste[['actual_time']].strftime('%H:%M:%S')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'strftime'

# %%
df = pd.DataFrame()
df['Time']=pd.to_datetime(orders_teste['actual_time'],format='%H:%M:%S').dt.time
# Out:
#           Time
# 0     12:00:15
# 1     10:28:10
# 2     10:40:50
# 3     09:41:47
# 4     10:07:53
# ...        ...
# 7290  13:49:02
# 7291  10:23:36
# 7292  12:11:55
# 7293  10:38:28
# 7294  22:49:00
#
# [7295 rows x 1 columns]

# %%
current_date_and_time = datetime.datetime.now()
print(current_date_and_time)

hours = 5
hours_added = datetime.timedelta(hours = hours)

future_date_and_time = current_date_and_time + hours_added

print(future_date_and_time)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-c7850b66d288> in <module>
# ----> 1 current_date_and_time = datetime.datetime.now()
#       2 print(current_date_and_time)
#       3
#       4 hours = 5
#       5 hours_added = datetime.timedelta(hours = hours)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
pd.to_datetime(df.Time).dt.strftime('%H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-4381b2869fea> in <module>
# ----> 1 pd.to_datetime(df.Time).dt.strftime('%H:%M:%S')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     801             result = arg.map(cache_array)
#     802         else:
# --> 803             values = convert_listlike(arg._values, format)
#     804             result = arg._constructor(values, index=arg.index, name=arg.name)
#     805     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
# ...

# %%
from datetime import datetime, date, time, timedelta

# %%
from datetime import timedelta

for i in range(len(orders_teste['actual_time'])):
    a=df['Time'][i]
    b=orders_teste['total_minutes'][i]
    df['Time'][i] = df['Time'][i] + timedelta(minutes=b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-08958153708b> in <module>
#       4     a=df['Time'][i]
#       5     b=orders_teste['total_minutes'][i]
# ----> 6     df['Time'][i] = df['Time'][i].time() + timedelta(minutes=b)
#
# AttributeError: 'datetime.time' object has no attribute 'time'

# %% [markdown]
# <H1>Uploading into PostgreSQL</H1>

# %%
t1 = datetime.time(hours, minutes, second) + timedelta(minutes=m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-4dde6f817256> in <module>
#       5 date_format_str = '%H:%M:%S'
#       6 # create datetime object from timestamp string
# ----> 7 given_time = datetime.strftime(time_str, date_format_str)
#       8 print('Given timestamp: ', given_time)
#       9 n = 3
#
# TypeError: descriptor 'strftime' for 'datetime.date' objects doesn't apply to a 'str' object

# %%
import sqlalchemy as db
import pandas as pd
import os
import glob

# %%
date_format_str
# Out:
# '%H:%M:%S'

# %%
time_str
# Out:
# '11:12:22'

# %%
# ?datetime.time()
# Out:
# Object `datetime.time()` not found.

# %%
extension = 'csv'
result = glob.glob('*.{}'.format(extension))
print(result)
# Out:
# ['storebranch.csv', 'orders.csv', 'shoppers.csv', 'order_product.csv']

# %%
engine = db.create_engine('postgresql+psycopg2://postgres:admin@localhost/cornershop')
conn = engine.connect()

# %%
for f in result:
    x = pd.read_csv(f,low_memory=False)
    x.to_sql(name=f.replace('.csv',''), con=conn, if_exists='replace', index=False)
